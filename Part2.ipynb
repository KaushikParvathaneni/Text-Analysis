# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import nltk
from textblob import TextBlob

# %%
new = pd.read_csv('newinfo.csv')

# %%
new
# Out:
#       Unnamed: 0    ID                    Target  \
# 0              0   101                   Atheism
# 1              1   102                   Atheism
# 2              2   103                   Atheism
# 3              3   104                   Atheism
# 4              4   105                   Atheism
# ...          ...   ...                       ...
# 2809        2809  2910  Legalization of Abortion
# 2810        2810  2911  Legalization of Abortion
# 2811        2811  2912  Legalization of Abortion
# 2812        2812  2913  Legalization of Abortion
# 2813        2813  2914  Legalization of Abortion
#
#                                                   Tweet   Stance  \
# 0     dear lord thank u for all of ur blessings forg...  AGAINST
# 1     Blessed are the peacemakers, for they shall be...  AGAINST
# 2     I am not conformed to this world. I am transfo...  AGAINST
# 3     Salah should be prayed with #focus and #unders...  AGAINST
# ...

# %%
fil_max_info = new['FILTERED']

# %%
fil_max_info
# Out:
# 0       dear lord thank u ur blessings forgive sins lo...
# 1       blessed peacemakers, shall called children god...
# 2       am conformed world. am transformed renewing mind.
# 3       salah should prayed warns against prayers done...
# 4       stay houses display yourselves times ignorance...
#                               ...
# 2809    there's law protecting unborn eagles, humans u...
# 2810                            am 1 3... had an abortion
# 2811    how dare say sexual preference choice, how dar...
# 2812    equal rights those 'born way', rights those ye...
# 2813    seals his legacy w/ 1/2 doz wins. agenda? stil...
# Name: FILTERED, Length: 2814, dtype: object

# %%
every_tweet_max_info = ''.join(new['FILTERED'])

# %%
#pos tagging
nltk.pos_tag(every_tweet_max_info.split())
# Out:
# [('dear', 'JJ'),
#  ('lord', 'NN'),
#  ('thank', 'NN'),
#  ('u', 'JJ'),
#  ('ur', 'JJ'),
#  ('blessings', 'NNS'),
#  ('forgive', 'JJ'),
#  ('sins', 'NNS'),
#  ('lord', 'RBR'),
#  ('give', 'JJ'),
#  ('strength', 'NN'),
#  ('energy', 'NN'),
#  ('busy', 'JJ'),
#  ('day', 'NN'),
#  ('aheadblessed', 'VBD'),
#  ('peacemakers,', 'NN'),
#  ('shall', 'MD'),
#  ('called', 'VB'),
#  ('children', 'NNS'),
#  ('god.', 'VB'),
#  ('matthew', 'RB'),
#  ('5:9am', 'CD'),
#  ('conformed', 'VBD'),
#  ('world.', 'NN'),
#  ('am', 'VBP'),
#  ('transformed', 'VBN'),
#  ('renewing', 'VBG'),
#  ('mind.salah', 'NN'),
#  ('should', 'MD'),
#  ('prayed', 'VB'),
#  ('warns', 'NNS'),
#  ('against', 'IN'),
#  ('prayers', 'NNS'),
#  ('done', 'VBN'),
#  ('surah', 'JJ'),
#  ('al-maoon', 'JJ'),
#  ('107:4-6stay', 'JJ'),
#  ('houses', 'NNS'),
#  ('display', 'VBP'),
#  ('yourselves', 'VBZ'),
#  ('times', 'NNS'),
#  ('ignorance."', 'JJ'),
#  ('[quran', 'VBD'),
#  ('33:33].#islamunsure', 'CD'),
#  ('whether', 'IN'),
# ...

# %%
R = TextBlob(every_tweet_max_info)

# %%
R.sentiment.polarity
# Out:
# 0.11589032412967894

# %%
pol_max = []
for i in every_tweet_max_info.split():
    pol_max.append(TextBlob(i).sentiment.polarity)

# %%
# TextBlob('good').sentiment.polarity #0.7
pol_max = np.array(pol_max)

# %%
len(pol_max)
# Out:
# 22989

# %%
pol_max.sum()/len(pol_max)
# Out:
# 0.01441731242486495

# %%
#took some words
positive_and_negative = pd.read_csv('words.csv')

# %%
positive_and_negative
# Out:
#       Unnamed: 0 Negative Sense Word List Positive Sense Word List
# 0              1                 abnormal                     able
# 1              2                  abolish                abundance
# 2              3               abominable               accelerate
# 3              4               abominably                   accept
# 4              5                abominate                  acclaim
# ...          ...                      ...                      ...
# 4715        4716                   zenana                      NaN
# 4716        4717                   zephyr                      NaN
# 4717        4718                     zero                      NaN
# 4718        4719                      zol                      NaN
# 4719        4720                   zombie                      NaN
#
# [4720 rows x 3 columns]

# %%
negative = positive_and_negative['Negative Sense Word List']

# %%
len(negative)
# Out:
# 4720

# %%
positive = positive_and_negative['Positive Sense Word List']

# %%
len(positive)
# Out:
# 4720

# %%
positive = list(positive)
negative = list(negative)

# %%
maximum_list = list(new['FILTERED'])
minimum_list = list(new['minimal_preprocessing'])

# %%
def pol_cal(list_data):    
    positive_pol = []
    negative_pol = []
    for sentence in list_data:
        count_positive = 0
        count_negative = 0
        sent_len = 0
        for word in sentence.split():
            sent_len = len(sentence.split())
            if word in positive:
                count_positive +=1
            elif word in negative:
                count_negative +=1
        positive_pol.append(count_positive/sent_len)
        negative_pol.append(count_negative/sent_len)
    return positive_pol, negative_pol

# %%
positive_pol_max = pol_cal(maximum_list)[0]
negative_pol_max = pol_cal(maximum_list)[1]

# %%
positive_pol_min = pol_cal(minimum_list)[0]
negative_pol_min = pol_cal(minimum_list)[1]

# %% [markdown]
# #### -What are the average polarity scores?

# %%
# What are the average polarity scores?
print('avg pos polarity of maximum filtered data:',np.array(positive_pol_max).mean())
print('avg neg polarity of maximum filtered data:',np.array(negative_pol_max).mean())
print('avg pos polarity of minimum filtered data:',np.array(positive_pol_min).mean())
print('avg neg polarity of minimum filtered data:',np.array(negative_pol_min).mean())

average_max = (np.array(positive_pol_max) + np.array(negative_pol_max)).sum()/len(np.array(positive_pol_max) + np.array(negative_pol_max))
print('Average polarity of all the max filtered data', average_max)

average_min = (np.array(positive_pol_min) + np.array(negative_pol_min)).sum()/len(np.array(positive_pol_min) + np.array(negative_pol_min))
print('Average polarity of all the min filtered data', average_min)
# Out:
# avg pos polarity of maximum filtered data: 0.20404161696875758
# avg neg polarity of maximum filtered data: 0.05258215253103428
# avg pos polarity of minimum filtered data: 0.14596958725950818
# avg neg polarity of minimum filtered data: 0.03681318377690839
# Average polarity of all the max filtered data 0.2566237694997919
# Average polarity of all the min filtered data 0.1827827710364166

# %% [markdown]
# #### -	What are the average polarity scores across different kinds of stances?

# %%
# What are the average polarity scores across different kinds of stances? 
def fil_new(new,unq_col_values, col_name):
    '''This function is used to filter the dataframes 
    Inputs:dataframe name (df), list of unique column names in that column (unique_col_values), the Column name it self(col_name)
    returns dataframes of each unique column name that was filtered
    '''
    new_frame = []
    for i in unq_col_values:
        new_frame.append(new[new[col_name] == i]) 
    return new_frame

# %%
st = new['Stance'].unique()
print(st)
# Out:
# ['AGAINST' 'FAVOR' 'NONE']

# %%
new['positive_pol_max'] = positive_pol_max
new['negative_pol_max'] = negative_pol_max
new['positive_pol_min'] = positive_pol_min
new['negative_pol_min'] = negative_pol_min

# %%
new['maximum_sum_of_pol'] = np.array(positive_pol_max) + np.array(negative_pol_max)
new['minimum_sum_of_pol'] = np.array(positive_pol_min) + np.array(negative_pol_min)

# %%
for i in range(0,len(st)):
    st_new = fil_new(new, st, 'Stance' )[i]
    temp_sum = np.array(fil_new(new, st, 'Stance' )[i]['maximum_sum_of_pol'])
    print(f'{st[i]}:')
    print(f'Average Positive polarity score for \'{st[i]}\' Stance  for max processing:' , st_new['positive_pol_max'].mean()) 
    print(f'Average Negative polarity score for \'{st[i]}\' Stance  for max processing:' , st_new['negative_pol_max'].mean()) 
    print(f'Average Polarity Score for \'{st[i]}\' Stance for max processing:' ,temp_sum.sum()/len(temp_sum), '\n')
# Out:
# AGAINST:
# Average Positive polarity score for 'AGAINST' Stance  for max processing: 0.1958230046222531
# Average Negative polarity score for 'AGAINST' Stance  for max processing: 0.05564965968599144
# Average Polarity Score for 'AGAINST' Stance for max processing: 0.2514726643082443
#
# FAVOR:
# Average Positive polarity score for 'FAVOR' Stance  for max processing: 0.2123240762795767
# Average Negative polarity score for 'FAVOR' Stance  for max processing: 0.04520653195413793
# Average Polarity Score for 'FAVOR' Stance for max processing: 0.2575306082337144
#
# NONE:
# Average Positive polarity score for 'NONE' Stance  for max processing: 0.21075538216821907
# Average Negative polarity score for 'NONE' Stance  for max processing: 0.05430277876552681
# Average Polarity Score for 'NONE' Stance for max processing: 0.26505816093374535

# %%
for i in range(0,len(st)):
    st_new = fil_new(new, st, 'Stance' )[i]
    temp_sum = np.array(fil_new(new, st, 'Stance' )[i]['minimum_sum_of_pol'])
    print(f'{st[i]}:')
    print(f'Average Positive polarity score for \'{st[i]}\' Stance  for min processing:' , st_new['positive_pol_min'].mean()) 
    print(f'Average Negative polarity score for \'{st[i]}\' Stance  for min processing:' , st_new['negative_pol_min'].mean()) 
    print(f'Average Polarity Score for \'{st[i]}\' Stance for min processing:' ,temp_sum.sum()/len(temp_sum), '\n')
# Out:
# AGAINST:
# Average Positive polarity score for 'AGAINST' Stance  for min processing: 0.14352769068630344
# Average Negative polarity score for 'AGAINST' Stance  for min processing: 0.03973998384237616
# Average Polarity Score for 'AGAINST' Stance for min processing: 0.18326767452867884
#
# FAVOR:
# Average Positive polarity score for 'FAVOR' Stance  for min processing: 0.15209119161506407
# Average Negative polarity score for 'FAVOR' Stance  for min processing: 0.03342875260288741
# Average Polarity Score for 'FAVOR' Stance for min processing: 0.1855199442179511
#
# NONE:
# Average Positive polarity score for 'NONE' Stance  for min processing: 0.14435303181730946
# Average Negative polarity score for 'NONE' Stance  for min processing: 0.034851312657275195
# Average Polarity Score for 'NONE' Stance for min processing: 0.17920434447458425

# %% [markdown]
# #### What are the average polarity scores across different targets?

# %%
# What are the average polarity scores across different targets?
tar = new['Target'].unique()

for i in range(0,len(tar)):
    tar_new = fil_new(new, tar, 'Target' )[i]
    temp_sum = np.array(fil_new(new, tar, 'Target' )[i]['maximum_sum_of_pol'])
    print(f'{tar[i]}:')
    print(f'Average Positive polarity score for \'{tar[i]}\' Target  for max processing:' , tar_new['positive_pol_max'].mean()) 
    print(f'Average Negative polarity score for \'{tar[i]}\' Target  for max processing:' , tar_new['negative_pol_max'].mean()) 
    print(f'Average Polarity score for \'{tar[i]}\' Target for max processing:' ,temp_sum.sum()/len(temp_sum), '\n')
# Out:
# Atheism:
# Average Positive polarity score for 'Atheism' Target  for max processing: 0.2076171385429442
# Average Negative polarity score for 'Atheism' Target  for max processing: 0.046652581940362765
# Average Polarity score for 'Atheism' Target for max processing: 0.2542697204833066
#
# Climate Change is a Real Concern:
# Average Positive polarity score for 'Climate Change is a Real Concern' Target  for max processing: 0.20278535417589805
# Average Negative polarity score for 'Climate Change is a Real Concern' Target  for max processing: 0.04090694116010569
# Average Polarity score for 'Climate Change is a Real Concern' Target for max processing: 0.24369229533600342
#
# Feminist Movement:
# Average Positive polarity score for 'Feminist Movement' Target  for max processing: 0.19556225857584553
# Average Negative polarity score for 'Feminist Movement' Target  for max processing: 0.06754353813375517
# ...

# %%
tar = new['Target'].unique()

for i in range(0,len(tar)):
    tar_new = fil_new(new, tar, 'Target' )[i]
    temp_sum = np.array(fil_new(new, tar, 'Target' )[i]['minimum_sum_of_pol'])
    print(f'{tar[i]}:')
    print(f'Average Positive polarity score for \'{tar[i]}\' Target  for min processing:' , tar_new['positive_pol_min'].mean()) 
    print(f'Average Negative polarity score for \'{tar[i]}\' Target  for min processing:' , tar_new['negative_pol_min'].mean()) 
    print(f'Average Polarity score for \'{tar[i]}\' Target for min processing:' ,temp_sum.sum()/len(temp_sum), '\n')
# Out:
# Atheism:
# Average Positive polarity score for 'Atheism' Target  for min processing: 0.15622857328966022
# Average Negative polarity score for 'Atheism' Target  for min processing: 0.033208363251543936
# Average Polarity score for 'Atheism' Target for min processing: 0.18943693654120392
#
# Climate Change is a Real Concern:
# Average Positive polarity score for 'Climate Change is a Real Concern' Target  for min processing: 0.14069122967925754
# Average Negative polarity score for 'Climate Change is a Real Concern' Target  for min processing: 0.027521392729881158
# Average Polarity score for 'Climate Change is a Real Concern' Target for min processing: 0.16821262240913842
#
# Feminist Movement:
# Average Positive polarity score for 'Feminist Movement' Target  for min processing: 0.14546387752575535
# Average Negative polarity score for 'Feminist Movement' Target  for min processing: 0.048545065295911564
# ...

# %% [markdown]
# #### What are the average polarity scores across targets and stances?

# %%
# What are the average polarity scores across targets and stances?
sts_new = [i for i in fil_new(new, st, 'Stance')]

# %%
for sn in sts_new:
    for i in range(0,len(tar)):
        tar_new = fil_new(st_new, tar, 'Target' )[i]
        temp_sum = np.array(fil_new(new, tar, 'Target' )[i]['minimum_sum_of_pol'])
        k = sn['Stance'].unique()[0]
        print(f'---------\'{k}\' Stance---------')
        print(f'{tar[i]}:')
        print(f'Average Positive polarity score for \'{tar[i]}\' Target and \'{k}\' Stance for min processing:' , tar_new['positive_pol_min'].mean()) 
        print(f'Average Negative polarity score for \'{tar[i]}\' Target and \'{k}\' Stance for min processing:' , tar_new['negative_pol_min'].mean()) 
        print(f'Average Polarity score for \'{tar[i]}\' Target and \'{k}\' Stance for min processing:' ,temp_sum.sum()/len(temp_sum), '\n')
# Out:
# ---------'AGAINST' Stance---------
# Atheism:
# Average Positive polarity score for 'Atheism' Target and 'AGAINST' Stance for min processing: 0.15675006673855602
# Average Negative polarity score for 'Atheism' Target and 'AGAINST' Stance for min processing: 0.04405683869345852
# Average Polarity score for 'Atheism' Target and 'AGAINST' Stance for min processing: 0.18943693654120392
#
# ---------'AGAINST' Stance---------
# Climate Change is a Real Concern:
# Average Positive polarity score for 'Climate Change is a Real Concern' Target and 'AGAINST' Stance for min processing: 0.15078995866534556
# Average Negative polarity score for 'Climate Change is a Real Concern' Target and 'AGAINST' Stance for min processing: 0.022174624997629205
# Average Polarity score for 'Climate Change is a Real Concern' Target and 'AGAINST' Stance for min processing: 0.16821262240913842
#
# ---------'AGAINST' Stance---------
# Feminist Movement:
# ...

# %%
for sn in sts_new:
    for i in range(0,len(tar)):
        tar_new = fil_new(st_new, tar, 'Target' )[i]
        temp_sum = np.array(fil_new(new, tar, 'Target' )[i]['maximum_sum_of_pol'])
        k = sn['Stance'].unique()[0]
        print(f'---------\'{k}\' Stance---------')
        print(f'{tar[i]}:')
        print(f'Average Positive polarity score for \'{tar[i]}\' Target and \'{k}\' Stance for max processing:' , tar_new['positive_pol_max'].mean()) 
        print(f'Average Negative polarity score for \'{tar[i]}\' Target and \'{k}\' Stance for max processing:' , tar_new['negative_pol_max'].mean()) 
        print(f'Average Polarity score for \'{tar[i]}\' Target and \'{k}\' Stance for min processing:' ,temp_sum.sum()/len(temp_sum), '\n')
# Out:
# ---------'AGAINST' Stance---------
# Atheism:
# Average Positive polarity score for 'Atheism' Target and 'AGAINST' Stance for max processing: 0.21156553490640953
# Average Negative polarity score for 'Atheism' Target and 'AGAINST' Stance for max processing: 0.0658590609670232
# Average Polarity score for 'Atheism' Target and 'AGAINST' Stance for min processing: 0.2542697204833066
#
# ---------'AGAINST' Stance---------
# Climate Change is a Real Concern:
# Average Positive polarity score for 'Climate Change is a Real Concern' Target and 'AGAINST' Stance for max processing: 0.2229092914360771
# Average Negative polarity score for 'Climate Change is a Real Concern' Target and 'AGAINST' Stance for max processing: 0.03984314296814296
# Average Polarity score for 'Climate Change is a Real Concern' Target and 'AGAINST' Stance for min processing: 0.24369229533600342
#
# ---------'AGAINST' Stance---------
# Feminist Movement:
# ...
